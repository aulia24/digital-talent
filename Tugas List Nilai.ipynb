# %%
import random

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas)

# TAMPILKAN:
# ganjil
# nilai > 70
# standar deviasi
# maksimum
# minimum
# modus
# Out:
# [34, 37, 64, 2, 10, 45, 10, 11, 11, 43, 11, 35, 38, 1, 24, 70, 95, 38, 11, 19, 23, 97, 42, 15, 15, 60, 81, 56, 14, 25, 11, 18, 46, 98, 7, 23, 31, 44, 55, 79, 31, 83, 12, 28, 46, 90, 74, 61, 57, 34, 76, 29, 44, 46, 92, 66, 21, 18, 10, 7, 38, 16, 8, 4, 54, 90, 5, 30, 62, 96, 71, 9, 29, 39, 31, 66, 52, 98, 48, 83, 34, 95, 44, 54, 24, 93, 94, 51, 65, 4, 25, 58, 72, 94, 28, 21, 11, 74, 31, 11, 62, 64, 55, 99, 58, 45, 58, 44, 38, 67, 83, 68, 33, 46, 79, 57, 40, 7, 9, 3, 72, 29, 54, 43, 94, 13, 63, 61, 99, 75, 60, 82, 1, 66, 68, 30, 53, 12, 88, 10, 32, 35, 8, 15, 42, 24, 59, 48, 61, 37, 50, 22, 93, 26, 94, 96, 30, 72, 31, 5, 3, 19, 31, 59, 47, 6, 2, 40, 37, 56, 10, 94, 73, 65, 96, 19, 46, 77, 21, 58, 89, 35, 86, 42, 79, 1, 97, 56, 61, 10, 2, 72, 80, 62, 65, 52, 88, 88, 14, 78, 41, 38, 27, 56, 2, 27, 38, 14, 72, 2, 47, 64, 38, 75, 99, 89, 1, 52, 76, 39, 65, 85, 23, 85, 62, 54, 80, 26, 47, 40, 59, 20, 62, 46, 79, 30, 15, 5, 52, 65, 69, 82, 88, 68, 35, 4, 90, 3, 11, 90]

# %%
# Nilai Ganjil

for n in nilaiTugas:
    if (n % 2 == 1): #maksudnya adalah angka apapun dibagi 2 mempunyai sisa 1
        print(n)
# Out:
# 37
# 45
# 11
# 11
# 43
# 11
# 35
# 1
# 95
# 11
# 19
# 23
# 97
# 15
# 15
# 81
# 25
# 11
# 7
# 23
# 31
# 55
# 79
# 31
# 83
# 61
# 57
# 29
# 21
# 7
# 5
# 71
# 9
# 29
# 39
# 31
# 83
# 95
# 93
# 51
# 65
# 25
# 21
# 11
# 31
# 11
# 55
# 99
# 45
# 67
# 83
# 33
# 79
# 57
# 7
# 9
# 3
# 29
# 43
# 13
# 63
# 61
# 99
# 75
# 1
# 53
# 35
# 15
# 59
# 61
# 37
# 93
# 31
# 5
# 3
# 19
# 31
# 59
# 47
# 37
# 73
# 65
# 19
# 77
# 21
# 89
# 35
# 79
# 1
# 97
# 61
# 65
# 41
# 27
# 27
# 47
# 75
# 99
# 89
# 1
# 39
# 65
# 85
# 23
# 85
# 47
# 59
# 79
# 15
# 5
# 65
# 69
# 35
# 3
# 11

# %%
# Nilai > 70

counter=0
for n in nilaiTugas:
    if n>=70:
        counter +=1
        print(n)
        print("angka >=70 :", counter)
# Out:
# 70
# angka >=70 : 1
# 95
# angka >=70 : 2
# 97
# angka >=70 : 3
# 81
# angka >=70 : 4
# 98
# angka >=70 : 5
# 79
# angka >=70 : 6
# 83
# angka >=70 : 7
# 90
# angka >=70 : 8
# 74
# angka >=70 : 9
# 76
# angka >=70 : 10
# 92
# angka >=70 : 11
# 90
# angka >=70 : 12
# 96
# angka >=70 : 13
# 71
# angka >=70 : 14
# 98
# angka >=70 : 15
# 83
# angka >=70 : 16
# 95
# angka >=70 : 17
# 93
# angka >=70 : 18
# 94
# angka >=70 : 19
# 72
# angka >=70 : 20
# 94
# angka >=70 : 21
# 74
# angka >=70 : 22
# 99
# angka >=70 : 23
# 83
# angka >=70 : 24
# 79
# angka >=70 : 25
# 72
# angka >=70 : 26
# 94
# angka >=70 : 27
# 99
# angka >=70 : 28
# 75
# angka >=70 : 29
# 82
# angka >=70 : 30
# 88
# angka >=70 : 31
# 93
# angka >=70 : 32
# 94
# angka >=70 : 33
# 96
# angka >=70 : 34
# 72
# angka >=70 : 35
# 94
# angka >=70 : 36
# 73
# angka >=70 : 37
# 96
# angka >=70 : 38
# 77
# angka >=70 : 39
# 89
# angka >=70 : 40
# 86
# angka >=70 : 41
# 79
# angka >=70 : 42
# 97
# angka >=70 : 43
# 72
# ...

# %%
#Menghitung Standar Deviasi

for i in range(len(nilaiTugas)):
    nilaiTugas[i]=int(nilaiTugas[i])
jumlah=0
for n in range(len(nilaiTugas)):
    jumlah +=nilaiTugas[i]

total = 0
for n in nilaiTugas:
    total = total + n
    rata = total / len(nilaiTugas)

sigma=0
for n in range(len(nilaiTugas)):
    x1 = (nilaiTugas[i]-rata)**2
    sigma+=x1

sd = (sigma/249)**0.5
print(sd)
# Out:
# 43.258603898473034

# %%
# Nilai Maksimum dan Minimum

maks=0    
for n in nilaiTugas:
    if n > maks:
        maks=n
print("nilai maksimum : ", maks)

minn=100
for m in nilaiTugas:
    if m < minn:
        minn=m
print("nilai minimum : ",minn)
# Out:
# nilai maksimum :  99
# nilai minimum :  1

# %%
# Menghitung Modus

modus=nilaiTugas[0]
jumlah= nilaiTugas.count(modus)
for n in nilaiTugas:
    jumlah_n=nilaiTugas.count(n)
    if jumlah_n>jumlah:
        modus=n
        jumlah=jumlah_n
print("nilai modus :",modus)
# Out:
# nilai modus : 11

# %%
# Out:
# nilai modus :  11
